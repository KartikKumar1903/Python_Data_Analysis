# %%
import pandas as pd

# %%
# Reading the csv file

df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Selecting one column
# ---

# %% [markdown]
# ## Syntax 1

# %%
# Select a column with [] (Preferred way to select a column)

df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# Check out the data type of a column

type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
# Series : attributes and methods

df_exams['gender'].index # RangeIndex(start=0, stop=1000, step=1)
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# ## Syntax 2

# %%
# Select a column with dot '.'

df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# Select a column with dot '.'  (pitfalls)

df_exams.math score
# Out:
#   Cell In[16], line 3
#     df_exams.math score
#                   ^
# SyntaxError: invalid syntax

# %%
# Select the same column using []

df_exams['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %% [markdown]
# # Selecting two or more columns

# %%
# Select two columns using [[]]

df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
# Check out the data type of the selection

type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Select 2 or more columns using [[]]

df_exams[['gender', 'writing score', 'math score', 'reading score', ]]
# Out:
#      gender  writing score  math score  reading score
# 0    female             74          72             72
# 1    female             88          69             90
# 2    female             93          90             95
# 3      male             44          47             57
# 4      male             75          76             78
# ..      ...            ...         ...            ...
# 995  female             95          88             99
# 996    male             55          62             55
# 997  female             65          59             71
# 998  female             77          68             78
# 999  female             86          77             86
#
# [1000 rows x 4 columns]

# %%
# We can't select 2 or more columns with "."

df_exams.'gender', 'math score'
# Out:
#   Cell In[23], line 3
#     df_exams.'gender', 'math score'
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Adding a new column

# %% [markdown]
# ## Adding a new column with a scalar value

# %%
# Adding a new column to dataframe

df_exams['language score'] = 70 
df_exams # All the rows will have same value (70).
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## Adding a new column with an array
#
# The dataframe has 1000 rows, so we need to create an array with 1000 elements.

# %%
# Import numpy

import numpy as np

# %%
# Create an array of 1000 elements

language_score = np.arange(0, 1000) 
# np.arange(0, 1000) is used to create an array which has 1000
# elements, from 0 to 999.

# %%
# Length of the array

len(language_score)
# Out:
# 1000

# %%
# Adding a new column to dataframe with an array

df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
# Create random integer numbers between 1 and 100

int_language_score = np.random.randint(1, 100, size = 1000)

# %%
# Min value inclusive and high value exclusive

min(int_language_score)
max(int_language_score)
# Out:
# np.int32(99)

# %%
# Adding a new column to dataframe with an array

df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 8
# 1                 7
# 2                60
# 3                 8
# 4                82
# ..              ...
# 995              44
# 996              11
# 997              60
# 998              14
# 999              19
#
# [1000 rows x 9 columns]

# %%
# Create random float number between 1 and 100

float_array = np.random.uniform(1, 100, size = 100)

# %% [markdown]
# ## assign()
#
# When to use assign?
# - Add multiple columns in a single line of code
# - When you need to overwrite the value of an existing columns (best practice)
#
# It returns a new object (a copy) with all the original columns in addition to the new ones.

# %%
# Create random numbers for our new score columns

score1 = np.random.randint(1, 100, size = 1000)
score2 = np.random.randint(1, 100, size = 1000)

# %%
# Create a series using the random numbers

series1 = pd.Series(score1, index = np.arange(0, 1000))
series2 = pd.Series(score2, index = np.arange(0, 1000))

# %%
# Using assign() to add multiple columns

df_exams.assign(score1 = series1, score2 = series2) # Creates a copy
df_exams = df_exams.assign(score1 = series1, score2 = series2)

# %%
# Show dataframe

df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                 8      60      85
# 1                 7      71      93
# 2                60      84      73
# 3                 8      83      64
# 4                82      91      87
# ..              ...     ...     ...
# 995              44      17      60
# 996              11      49       2
# 997              60      84      84
# 998              14      65      98
# 999              19       5      34
#
# [1000 rows x 11 columns]

# %% [markdown]
# ## insert()
#
# Inserts a new column at a specfic position or index.

# %%
# Using index() to add a column at a specific position or index.

df_exams.insert(1, 'test', series1)
# (index of column, name of column, array of values to be inserted)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    60        group B           bachelor's degree      standard
# 1    female    71        group C                some college      standard
# 2    female    84        group B             master's degree      standard
# 3      male    83        group A          associate's degree  free/reduced
# 4      male    91        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    17        group E             master's degree      standard
# 996    male    49        group C                 high school  free/reduced
# 997  female    84        group C                 high school  free/reduced
# 998  female    65        group D                some college      standard
# 999  female     5        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                 8      60      85
# 1                 7      71      93
# 2                60      84      73
# 3                 8      83      64
# 4                82      91      87
# ..              ...     ...     ...
# 995              44      17      60
# 996              11      49       2
# 997              60      84      84
# 998              14      65      98
# 999              19       5      34
#
# [1000 rows x 12 columns]
