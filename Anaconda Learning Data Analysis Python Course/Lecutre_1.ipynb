# %%
3
# Out:
# 3

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type("Hello World")
# Out:
# str

# %%
type(9)
# Out:
# int

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Hello World".upper())
print("Hello World".lower())
print("Hello World".title())
# Out:
# HELLO WORLD
# hello world
# Hello World

# %%
# Common String Methods.

print("Hello World".count("l"))

print("Hello World".replace("o", "u"))
# Out:
# 3
# Hellu Wurld

# %% [markdown]
# # Variables

# %%
message_1 = "I'm Learning Python"
message_1
# Out:
# "I'm Learning Python"

# %%
message_2 = "and it's fun"
message_2
# Out:
# "and it's fun"

# %%
message = message_1 + ' ' + message_2
message
# Out:
# "I'm Learning Python and it's fun"

# %% [markdown]
# ## f string

# %%
f'Hello World'
# Out:
# 'Hello World'

# %%
f'{message_1} {message_2}'
# Out:
# "I'm Learning Python and it's fun"

# %% [markdown]
# # List

# %%
countries = ['United States', 'India', 'China', 'Brazil']

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
print(countries[0])
print(countries[1])
print(countries[2])
print(countries[3])
# Out:
# United States
# India
# China
# Brazil

# %%
countries[-1]
# Out:
# 'Brazil'

# %%
countries[-4]
# Out:
# 'United States'

# %% [markdown]
# ## Slicing

# %%
# list_name[start : stop]
countries[0:3]
# Out:
# ['United States', 'India', 'China']

# %%
countries[0:1]
# Out:
# ['United States']

# %%
countries[1:]
# Out:
# ['India', 'China', 'Brazil']

# %%
countries[:2]
# Out:
# ['United States', 'India']

# %% [markdown]
# ## Adding elements to a list

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
# Adds element at the end of the list.

countries.append('Canada')

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
# Adds element at particular index.

countries.insert(0, 'Spain')

# %%
countries
# Out:
# ['Spain', 'United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries_2 = ['UK', 'Germany', 'Austria']

# %%
countries + countries_2
# Out:
# ['Spain',
#  'Spain',
#  'United States',
#  'India',
#  'China',
#  'Brazil',
#  'Canada',
#  'Canada',
#  'UK',
#  'Germany',
#  'Austria']

# %%
nested_list = [countries, countries_2]

# %%
nested_list
# Out:
# [['Spain',
#   'Spain',
#   'United States',
#   'India',
#   'China',
#   'Brazil',
#   'Canada',
#   'Canada'],
#  ['UK', 'Germany', 'Austria']]

# %% [markdown]
# ## Removing elements from list

# %%
countries = ['United States', 'India', 'China', 'Brazil']

# %%
countries.remove('United States')

# %%
countries
# Out:
# ['India', 'China', 'Brazil']

# %%
countries.pop(-1)
# Out:
# 'Brazil'

# %%
countries
# Out:
# ['India', 'China']

# %%
del countries[0]

# %%
countries
# Out:
# ['China']

# %% [markdown]
# ## Sorting a list

# %%
numbers = [4, 3, 10, 7, 1, 2]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 3, 4, 7, 10]

# %%
numbers = [4, 3, 10, 7, 1, 2]
numbers.sort(reverse=True)
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %% [markdown]
# ## Updating an element in list

# %%
numbers[0] = 1000
numbers
# Out:
# [1000, 7, 4, 3, 2, 1]

# %% [markdown]
# ## Copying a list

# %%
countries = ['United States', 'India', 'China', 'Brazil']
new_list = countries[:]

# %%
new_list
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
new_list_2 =  countries.copy()

# %%
new_list_2
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %% [markdown]
# # Dictionary

# %%
my_dict = {'key1':'value1', 'key2':'value2'}

# %%
my_data = {'name':'Kartik', 'age':21}

# %%
my_data
# Out:
# {'name': 'Kartik', 'age': 21}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Kartik', 21])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Kartik'), ('age', 21)])

# %%
my_data['height'] = 1.7

# %%
my_data
# Out:
# {'name': 'Kartik', 'age': 21, 'height': 1.7}

# %%
my_data.update({'height':1.8})

# %%
my_data
# Out:
# {'name': 'Kartik', 'age': 21, 'height': 1.8}

# %% [markdown]
# ## Copy a dictionary

# %%
new_dict = my_data.copy()

# %%
new_dict
# Out:
# {'name': 'Kartik', 'age': 21, 'height': 1.8}

# %% [markdown]
# ## Removing an element from Dictionary

# %%
my_data.pop('name')
# Out:
# 'Kartik'

# %%
my_data
# Out:
# {'age': 21, 'height': 1.8}

# %%
del my_data['age']

# %%
my_data
# Out:
# {'height': 1.8}

# %%
# To remove all elements from dictionary

my_data.clear()

# %%
my_data
# Out:
# {}
